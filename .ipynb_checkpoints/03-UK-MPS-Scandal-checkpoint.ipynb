# %% [markdown]
# # 案例：2009年英国国会议员开支丑闻
#
#
# MPs expenses scandal
#
# https://github.com/data-journalism/data-journalism.github.io/discussions/54

# %%
import pandas as pd

import pylab as plt

plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号, 注意['SimHei']对应这句不行.
plt.style.use('ggplot')

# %%
ls './data/'
# Out:
# MPs' expenses claims, Jul-Dec, 2009.xlsx
# data.js*

# %%
df = pd.read_excel("./data/MPs' expenses claims, Jul-Dec, 2009.xlsx")
df.head()
# Out:
#   Name of member                  Allowance Type  Expenditure Type  \
# 0   Adam Afriyie  Office running costs (IEP/AOE)       Incidentals
# 1   Adam Afriyie  Office running costs (IEP/AOE)       Incidentals
# 2   Adam Afriyie  Office running costs (IEP/AOE)       Incidentals
# 3  Adam Holloway      Communications Expenditure  Delivery charges
# 4  Adam Holloway      Communications Expenditure  Delivery charges
#
#                   Date Amount, £
# 0  2009-07-03 00:00:00    111.09
# 1  2009-11-05 00:00:00    111.09
# 2  2009-11-05 00:00:00     51.75
# 3  2009-11-10 00:00:00    258.22
# 4  2009-12-10 00:00:00    879.66

# %%
df.columns
# Out:
# Index(['Name of member', 'Allowance Type', 'Expenditure Type', 'Date',
#        'Amount, £'],
#       dtype='object')

# %%
len(df)
# Out:
# 38925

# %%
df.describe()
# Out:
#          Name of member                  Allowance Type Expenditure Type  \
# count             38925                           38925            38925
# unique              643                               5               39
# top     Danny Alexander  Office running costs (IEP/AOE)      Incidentals
# freq                173                           25787             8672
#
#                        Date  Amount, £
# count                 38925      38925
# unique                  140      14441
# top     2009-12-21 00:00:00         50
# freq                    828        857

# %% [markdown]
# ## 清洗数据

# %%
df[df['Amount, £']=='Amount']
# Out:
#       Name of member  Allowance Type  Expenditure Type  Date Amount, £
# 27710    Member Name  Allowance Type  Expenditure Type  Date    Amount

# %%
df = df[df['Amount, £']!='Amount']

# %%
df[df['Name of member']=='John Randall']
# Out:
#       Name of member                  Allowance Type       Expenditure Type  \
# 22221   John Randall  Office running costs (IEP/AOE)    Accommodation costs
# 22222   John Randall  Office running costs (IEP/AOE)  Other equipment lease
#
#                       Date Amount, £
# 22221  2009-08-20 00:00:00     -2134
# 22222  2009-07-01 00:00:00     25.08

# %%
df['Amount, £'] = [abs(float(i)) for i in df['Amount, £']]

# %% [markdown]
# ## 描述数据

# %%
df[['Name of member', 'Amount, £']].groupby("Name of member").agg('sum')
# Out:
#                Amount, £
# Name of member
# Adam Afriyie      273.93
# Adam Holloway    7415.06
# Adam Ingram     18578.90
# Adam Price       7874.73
# Adrian Bailey   10668.61
# ...                  ...
# William Hague    7370.98
# William McCrea  24689.34
# William Rennie  27257.33
# Willie Bain          822
# Yvette Cooper   21450.30
#
# [643 rows x 1 columns]

# %%
dat1 = df[['Name of member', 'Amount, £']].groupby("Name of member").agg('sum')
dat1 = dat1.sort_values(by=['Amount, £'], ascending = False)
dat1[:10]
# Out:
#                  Amount, £
# Name of member
# Graham Allen      42753.53
# Michael Foster    39999.69
# Mark Hunter       34779.11
# Gordon Banks      34471.90
# Lynda Waltho      34288.55
# Joan Humble       33395.89
# Phil Wilson       33031.23
# Barbara Follett   32861.14
# Sian James        32495.32
# Helen Jones       32209.45

# %%
dat1['Rank'] = range(1, len(dat1)+1)

# %%
dat1[:10]
# Out:
#                  Amount, £  Rank
# Name of member
# Graham Allen      42753.53     1
# Michael Foster    39999.69     2
# Mark Hunter       34779.11     3
# Gordon Banks      34471.90     4
# Lynda Waltho      34288.55     5
# Joan Humble       33395.89     6
# Phil Wilson       33031.23     7
# Barbara Follett   32861.14     8
# Sian James        32495.32     9
# Helen Jones       32209.45    10

# %%
plt.figure(figsize =(16, 6), dpi = 100)

plt.plot(dat1['Rank'], dat1['Amount, £'], 'ro')
# plt.yscale('log')
# plt.xscale('log')

plt.xlabel('Rank')
plt.ylabel('Amount, £')
plt.show()

# %%
plt.figure(figsize =(16, 6), dpi = 100)

dat10 = dat1[:10]
plt.plot(dat10['Rank'], dat10['Amount, £'], 'ro')
# plt.yscale('log')
# plt.xscale('log')

plt.xlabel('Rank')
plt.ylabel('Amount, £')
plt.show()

# %%
dat2 = df[['Allowance Type', 'Amount, £']].groupby("Allowance Type").agg('sum')
dat2 = dat2.sort_values(by=['Amount, £'], ascending = False)
dat2
# Out:
#                                                      Amount, £
# Allowance Type
# Office running costs (IEP/AOE)                      4561001.11
# Cost of staying away from the main home (ACA/PAAE)  3160432.72
# Communications Expenditure                          2510511.02
# Staffing non-payroll                                  24414.17

# %%
dat3 = df[['Expenditure Type', 'Amount, £']].groupby("Expenditure Type").agg('sum')
dat3 = dat3.sort_values(by=['Amount, £'], ascending = False)
dat3
# Out:
#                                     Amount, £
# Expenditure Type
# Accommodation costs                1809184.32
# Publications                       1097722.44
# Mortgage interest                  1056568.92
# Delivery charges                   1019891.50
# Rent                                969231.40
# Incidentals                         806222.41
# Telephones                          677887.23
# Other household costs               463874.76
# Subsistence                         373680.38
# Advertising                         261207.10
# Council tax                         226974.67
# Agencies etc                        220883.47
# Constituency Association payments   187676.45
# Utilities                           172737.37
# Other equipment lease               141508.52
# Websites                            131689.98
# IT equipment purchase               117466.40
# Professional fees                    90381.10
# Other equipment purchase             82802.68
# Maintenance, janitorial              79518.88
# Hotel Expenses                       70102.59
# Petty cash                           47442.51
# Payments to individuals              42585.55
# Member travel (AOE)                  31841.92
# Staff Subsistence                    24401.87
# Staff office purchases               22137.03
# Staff travel rail                     8195.26
# Staff telephone expenses              6965.79
# IT equipment lease                    4382.88
# Staff subsistence                     4071.69
# Staff travel car                      2888.88
# Staff use of home expenses            1969.68
# Staff travel air                       800.41
# Staff travel parking                   697.74
# Staff travel taxi                      521.54
# Staff travel public transport          190.85
# General Running Costs                   40.55
# Staff travel tolls                      12.30

# %%
plt.figure(figsize =(16, 4), dpi = 100)
dat3['Amount, £'].plot(kind = 'bar')
plt.yscale('log')
plt.show()

# %% [markdown]
# ## 桑基图

# %%
from pyecharts import options as opts
from pyecharts.charts import Sankey

nodes = [
    {"name": "category1"},
    {"name": "category2"},
    {"name": "category3"},
    {"name": "category4"},
    {"name": "category5"},
    {"name": "category6"},
]

links = [
    {"source": "category1", "target": "category2", "value": 10},
    {"source": "category2", "target": "category3", "value": 15},
    {"source": "category3", "target": "category4", "value": 20},
    {"source": "category5", "target": "category6", "value": 25},
]
c = (
    Sankey()
    .add(
        "sankey",
        nodes,
        links,
        linestyle_opt=opts.LineStyleOpts(opacity=0.2, curve=0.5, color="source"),
        label_opts=opts.LabelOpts(position="right"),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="Sankey-基本示例"))
    #.render("sankey_base.html")
    .render_notebook()
)

c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="519b03395ede41a3b9ccfaf970f203e9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_519b03395ede41a3b9ccfaf970f203e9 = echarts.init(
#                     document.getElementById('519b03395ede41a3b9ccfaf970f203e9'), 'white', {renderer: 'canvas'});
#                 var option_519b03395ede41a3b9ccfaf970f203e9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "sankey",
#             "name": "sankey",
#             "data": [
#                 {
#                     "name": "category1"
#                 },
#                 {
#                     "name": "category2"
#                 },
#                 {
#                     "name": "category3"
#                 },
#                 {
#                     "name": "category4"
#                 },
#                 {
#                     "name": "category5"
#                 },
#                 {
#                     "name": "category6"
#                 }
#             ],
#             "links": [
#                 {
#                     "source": "category1",
#                     "target": "category2",
#                     "value": 10
#                 },
#                 {
#                     "source": "category2",
#                     "target": "category3",
#                     "value": 15
#                 },
#                 {
#                     "source": "category3",
#                     "target": "category4",
#                     "value": 20
#                 },
#                 {
#                     "source": "category5",
#                     "target": "category6",
#                     "value": 25
#                 }
#             ],
#             "left": "5%",
#             "top": "5%",
#             "right": "20%",
#             "bottom": "5%",
#             "nodeWidth": 20,
#             "nodeGap": 8,
#             "nodeAlign": "justify",
#             "layoutIteration": 32,
#             "orient": "horizontal",
#             "draggable": true,
#             "focusNodeAdjacency": false,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 0.2,
#                 "curveness": 0.5,
#                 "type": "solid",
#                 "color": "source"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "sankey"
#             ],
#             "selected": {
#                 "sankey": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Sankey-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_519b03395ede41a3b9ccfaf970f203e9.setOption(option_519b03395ede41a3b9ccfaf970f203e9);
#         });
#     </script>

# %%
dat4 = df[['Allowance Type','Expenditure Type', 'Amount, £']].groupby(['Expenditure Type', 'Allowance Type'],  as_index = False).agg('sum')
dat4 = dat4.sort_values(by=['Amount, £'], ascending = False)
dat4
# Out:
#                      Expenditure Type  \
# 0                 Accommodation costs
# 20                       Publications
# 13                  Mortgage interest
# 5                    Delivery charges
# 21                               Rent
# 10                        Incidentals
# 35                         Telephones
# 16              Other household costs
# 34                        Subsistence
# 1                         Advertising
# 4                         Council tax
# 2                        Agencies etc
# 3   Constituency Association payments
# 36                          Utilities
# 14              Other equipment lease
# 37                           Websites
# 9               IT equipment purchase
# 19                  Professional fees
# 15           Other equipment purchase
# 11            Maintenance, janitorial
# 7                      Hotel Expenses
# 18                         Petty cash
# 17            Payments to individuals
# 12                Member travel (AOE)
# 22                  Staff Subsistence
# 23             Staff office purchases
# 30                  Staff travel rail
# 25           Staff telephone expenses
# 8                  IT equipment lease
# 24                  Staff subsistence
# 27                   Staff travel car
# 33         Staff use of home expenses
# 26                   Staff travel air
# 28               Staff travel parking
# 31                  Staff travel taxi
# 29      Staff travel public transport
# 6               General Running Costs
# 32                 Staff travel tolls
#
#                                        Allowance Type   Amount, £
# 0                      Office running costs (IEP/AOE)  1809184.32
# 20                         Communications Expenditure  1097722.44
# 13  Cost of staying away from the main home (ACA/P...  1056568.92
# 5                          Communications Expenditure  1019891.50
# 21  Cost of staying away from the main home (ACA/P...   969231.40
# 10                     Office running costs (IEP/AOE)   806222.41
# 35                     Office running costs (IEP/AOE)   677887.23
# 16  Cost of staying away from the main home (ACA/P...   463874.76
# 34  Cost of staying away from the main home (ACA/P...   373680.38
# 1                          Communications Expenditure   261207.10
# 4   Cost of staying away from the main home (ACA/P...   226974.67
# 2                      Office running costs (IEP/AOE)   220883.47
# 3                      Office running costs (IEP/AOE)   187676.45
# 36                     Office running costs (IEP/AOE)   172737.37
# 14                     Office running costs (IEP/AOE)   141508.52
# 37                         Communications Expenditure   131689.98
# 9                      Office running costs (IEP/AOE)   117466.40
# 19                     Office running costs (IEP/AOE)    90381.10
# 15                     Office running costs (IEP/AOE)    82802.68
# 11                     Office running costs (IEP/AOE)    79518.88
# 7   Cost of staying away from the main home (ACA/P...    70102.59
# 18                     Office running costs (IEP/AOE)    47442.51
# 17                     Office running costs (IEP/AOE)    42585.55
# 12                     Office running costs (IEP/AOE)    31841.92
# 22                               Staffing non-payroll    24401.87
# 23                     Office running costs (IEP/AOE)    22137.03
# 30                     Office running costs (IEP/AOE)     8195.26
# 25                     Office running costs (IEP/AOE)     6965.79
# 8                      Office running costs (IEP/AOE)     4382.88
# 24                     Office running costs (IEP/AOE)     4071.69
# 27                     Office running costs (IEP/AOE)     2888.88
# 33                     Office running costs (IEP/AOE)     1969.68
# 26                     Office running costs (IEP/AOE)      800.41
# 28                     Office running costs (IEP/AOE)      697.74
# 31                     Office running costs (IEP/AOE)      521.54
# 29                     Office running costs (IEP/AOE)      190.85
# 6                      Office running costs (IEP/AOE)       40.55
# 32                               Staffing non-payroll       12.30

# %%
nodes = dat4['Allowance Type'].unique().tolist() + dat4['Expenditure Type'].unique().tolist()
nodes = [{'name': i} for i in nodes]
links = [{'source': dat4['Allowance Type'][i], 'target': dat4['Expenditure Type'][i], 'value': dat4['Amount, £'][i]}  for i in dat4.index]

# %%
from pyecharts import options as opts
from pyecharts.charts import Sankey

s = (
    Sankey()
    .add(
        "sankey",
        nodes,
        links,
        linestyle_opt=opts.LineStyleOpts(opacity=0.2, curve=0.5, color="source"),
        label_opts=opts.LabelOpts(position="right"),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="Sankey Graph of UK MPS"))
)

s.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a47752b556b44adab6778945d76dc2ee" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a47752b556b44adab6778945d76dc2ee = echarts.init(
#                     document.getElementById('a47752b556b44adab6778945d76dc2ee'), 'white', {renderer: 'canvas'});
#                 var option_a47752b556b44adab6778945d76dc2ee = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "sankey",
#             "name": "sankey",
#             "data": [
#                 {
#                     "name": "Office running costs (IEP/AOE)"
#                 },
#                 {
#                     "name": "Communications Expenditure"
#                 },
#                 {
#                     "name": "Cost of staying away from the main home (ACA/PAAE)"
#                 },
#                 {
#                     "name": "Staffing non-payroll"
#                 },
#                 {
#                     "name": "Accommodation costs"
#                 },
#                 {
#                     "name": "Publications"
#                 },
#                 {
#                     "name": "Mortgage interest"
#                 },
#                 {
#                     "name": "Delivery charges"
#                 },
#                 {
#                     "name": "Rent"
#                 },
#                 {
#                     "name": "Incidentals"
#                 },
#                 {
#                     "name": "Telephones"
#                 },
#                 {
#                     "name": "Other household costs"
#                 },
#                 {
#                     "name": "Subsistence"
#                 },
#                 {
#                     "name": "Advertising"
#                 },
#                 {
#                     "name": "Council tax"
#                 },
#                 {
#                     "name": "Agencies etc"
#                 },
#                 {
#                     "name": "Constituency Association payments"
#                 },
#                 {
#                     "name": "Utilities"
#                 },
#                 {
#                     "name": "Other equipment lease"
#                 },
#                 {
#                     "name": "Websites"
#                 },
#                 {
#                     "name": "IT equipment purchase"
#                 },
#                 {
#                     "name": "Professional fees"
#                 },
#                 {
#                     "name": "Other equipment purchase"
#                 },
#                 {
#                     "name": "Maintenance, janitorial"
#                 },
#                 {
#                     "name": "Hotel Expenses"
#                 },
#                 {
#                     "name": "Petty cash"
#                 },
#                 {
#                     "name": "Payments to individuals"
#                 },
#                 {
#                     "name": "Member travel (AOE)"
#                 },
#                 {
#                     "name": "Staff Subsistence"
#                 },
#                 {
#                     "name": "Staff office purchases"
#                 },
#                 {
#                     "name": "Staff travel rail"
#                 },
#                 {
#                     "name": "Staff telephone expenses"
#                 },
#                 {
#                     "name": "IT equipment lease"
#                 },
#                 {
#                     "name": "Staff subsistence"
#                 },
#                 {
#                     "name": "Staff travel car"
#                 },
#                 {
#                     "name": "Staff use of home expenses"
#                 },
#                 {
#                     "name": "Staff travel air"
#                 },
#                 {
#                     "name": "Staff travel parking"
#                 },
#                 {
#                     "name": "Staff travel taxi"
#                 },
#                 {
#                     "name": "Staff travel public transport"
#                 },
#                 {
#                     "name": "General Running Costs"
#                 },
#                 {
#                     "name": "Staff travel tolls"
#                 }
#             ],
#             "links": [
#                 {
#                     "source": "Office running costs (IEP/AOE)",
#                     "target": "Accommodation costs",
#                     "value": 1809184.3200000054
#                 },
#                 {
#                     "source": "Communications Expenditure",
#                     "target": "Publications",
#                     "value": 1097722.4399999988
#                 },
#                 {
#                     "source": "Cost of staying away from the main home (ACA/PAAE)",
#                     "target": "Mortgage interest",
#                     "value": 1056568.9200000013
#                 },
#                 {
#                     "source": "Communications Expenditure",
#                     "target": "Delivery charges",
#                     "value": 1019891.5000000002
#                 },
#                 {
#                     "source": "Cost of staying away from the main home (ACA/PAAE)",
#                     "target": "Rent",
#                     "value": 969231.4000000001
#                 },
#                 {
#                     "source": "Office running costs (IEP/AOE)",
#                     "target": "Incidentals",
#                     "value": 806222.4099999958
#                 },
#                 {
#                     "source": "Office running costs (IEP/AOE)",
#                     "target": "Telephones",
#                     "value": 677887.2300000067
#                 },
#                 {
#                     "source": "Cost of staying away from the main home (ACA/PAAE)",
#                     "target": "Other household costs",
#                     "value": 463874.7600000004
#                 },
#                 {
#                     "source": "Cost of staying away from the main home (ACA/PAAE)",
#                     "target": "Subsistence",
#                     "value": 373680.38
#                 },
#                 {
#                     "source": "Communications Expenditure",
#                     "target": "Advertising",
#                     "value": 261207.10000000038
#                 },
#                 {
#                     "source": "Cost of staying away from the main home (ACA/PAAE)",
#                     "target": "Council tax",
#                     "value": 226974.67
#                 },
#                 {
#                     "source": "Office running costs (IEP/AOE)",
#                     "target": "Agencies etc",
#                     "value": 220883.47000000003
#                 },
#                 {
#                     "source": "Office running costs (IEP/AOE)",
#                     "target": "Constituency Association payments",
#                     "value": 187676.45000000004
#                 },
#                 {
#                     "source": "Office running costs (IEP/AOE)",
#                     "target": "Utilities",
#                     "value": 172737.3700000001
#                 },
#                 {
#                     "source": "Office running costs (IEP/AOE)",
#                     "target"

# %%
s.render("sankey_mps.html")
# Out:
# '/Users/datalab/github/data-journalism.github.io/notebook/sankey_mps.html'

# %% [markdown]
# https://data-journalism.github.io/notebook/sankey_mps.html
