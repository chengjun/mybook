# %% [markdown]
# # The 1st Chapter
#
# Beginning Python

# %%
pip install RISE
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Print

# %%
print('hello, world!')
# Out:
# hello, world!

# %%
"The Spannish Inquinision"
# Out:
# 'The Spannish Inquinision'

# %% [markdown]
# ## Number

# %%
2 + 2
# Out:
# 4

# %%
53272+2352323
# Out:
# 2405595

# %%
1/2
# Out:
# 0.5
